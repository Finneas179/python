# %%
import  matplotlib.pyplot as plt
import  pandas as  pd
import  numpy as np

# %%
fig,ax=plt.subplots()
ax.plot(['a','b','c'],[1,2,3])
plt.show()

# %%
fig=plt.figure()
ax=fig.add_subplot()
x=['a','b','c']
y=np.array([1,3,5])
ax.plot(x,y)
plt.show()
