# %%
import matplotlib.pyplot as plt
import pandas as pd
import  numpy as np

# %%
fig,ax=plt.subplots()
ax.plot([0,1,3],[1,3,4],'-.k')
ax.plot([0,1,3],[3,5,6],'-g',marker='v')
# plt.xlim(0,3)
# plt.ylim(3,6)
plt.axis([0,3,3,6])#一样
plt.show()
