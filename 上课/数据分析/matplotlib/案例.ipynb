# %%
import matplotlib.pyplot as plt

# %%
fig,ax=plt.subplots()
x=list(range(1,8))
wuhan=[15,20,22,23,20,18,16]
hei=[-10,-8,-12,-10,-8,-6,1]
ax.plot(x,wuhan,color='r',linestyle='-',marker='o')
ax.plot(x,hei,color='b',linestyle='-',marker='o')
