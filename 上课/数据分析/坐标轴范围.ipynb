# %%
import matplotlib.pyplot as plt
import pandas as pd
import  numpy as np

# %%
fig,ax=plt.subplots()
ax.plot([0,1,3],[1,3,4],'-.k')
ax.plot([0,1,3],[3,5,6],'-g',marker='v')
plt.xlim(0,3)
# Out:
# (0.0, 3.0)
